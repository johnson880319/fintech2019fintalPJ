# %%
# coding=Big5
import pandas as pd
import sys
taifex = pd.read_csv('Daily_2018_08_20.csv',encoding="big5")
taifex.tail()
# Out:
# /home/bala/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             成交日期     商品代號     到期月份(週別)    成交時間     成交價格  成交數量(B+S) 近月價格 遠月價格  \
# 245164  20180820  XIF      201810        93706  12619.0          2    -    -
# 245165  20180820  XIF      201810        94602  12652.0         10    -    -
# 245166  20180820  XIF      201810        94607  12652.0         10    -    -
# 245167  20180820  XIF      201810       113501  12661.0          2    -    -
# 245168  20180820  XIF      201810       133722  12632.0          2    -    -
#
#        開盤集合競價
# 245164
# 245165
# 245166
# 245167
# 245168

# %%
taifex.drop(taifex.loc[taifex['商品代號']!='TX     '].index, inplace=True)
taifex.tail()
# Out:
#             成交日期     商品代號     到期月份(週別)    成交時間     成交價格  成交數量(B+S) 近月價格 遠月價格  \
# 242571  20180820  TX       201906       133352  10535.0          2    -    -
# 242572  20180820  TX       201906       134206  10535.0          2    -    -
# 242573  20180820  TX       201906       134332  10535.0          2    -    -
# 242574  20180820  TX       201906       134403  10534.0          2    -    -
# 242575  20180820  TX       201906       134421  10535.0          2    -    -
#
#        開盤集合競價
# 242571
# 242572
# 242573
# 242574
# 242575

# %%
date = taifex.iat[-1,0]
taifex.drop(taifex.loc[taifex['成交日期']!=date].index, inplace=True)
taifex.tail()
# Out:
#             成交日期     商品代號     到期月份(週別)    成交時間     成交價格  成交數量(B+S) 近月價格 遠月價格  \
# 242571  20180820  TX       201906       133352  10535.0          2    -    -
# 242572  20180820  TX       201906       134206  10535.0          2    -    -
# 242573  20180820  TX       201906       134332  10535.0          2    -    -
# 242574  20180820  TX       201906       134403  10534.0          2    -    -
# 242575  20180820  TX       201906       134421  10535.0          2    -    -
#
#        開盤集合競價
# 242571
# 242572
# 242573
# 242574
# 242575

# %%
expiremonth = taifex.iat[0,2]
taifex.drop(taifex.loc[taifex['到期月份(週別)']!=expiremonth].index, inplace=True)
taifex.tail()
# Out:
#             成交日期     商品代號     到期月份(週別)    成交時間     成交價格  成交數量(B+S) 近月價格 遠月價格  \
# 240352  20180820  TX       201809       134459  10671.0          2    -    -
# 240353  20180820  TX       201809       134459  10671.0          2    -    -
# 240354  20180820  TX       201809       134459  10671.0         10    -    -
# 240355  20180820  TX       201809       134459  10672.0          2    -    -
# 240356  20180820  TX       201809       134500  10671.0          4    -    -
#
#        開盤集合競價
# 240352
# 240353
# 240354
# 240355
# 240356

# %%
open = taifex.iat[0,4]
close = taifex.iat[-1,4]
high = taifex['成交價格'].max()
low = taifex['成交價格'].min()
print('%d %d %d %d' % (open, high, low, close))
# Out:
# 10687 10715 10652 10671
