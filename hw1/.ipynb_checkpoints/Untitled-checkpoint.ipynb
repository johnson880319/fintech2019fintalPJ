# %%
import pandas as pd
taifex = pd.read_csv('small_Daily_2018_10_01.csv',encoding="big5")
taifex.tail()
# Out:
#         成交日期     商品代號  到期月份(週別)   成交時間    成交價格  成交數量(B+S) 近月價格 遠月價格 開盤集合競價
# 14  20180929  BRF        201812   5511  2525.5          2    -    -
# 15  20180929  BRF        201812  10819  2527.0          2    -    -
# 16  20180929  BRF        201812  11008  2527.0          4    -    -
# 17  20180929  BRF        201812  11241  2526.0          4    -    -
# 18  20180929  BRF        201812  14556  2523.0          2    -    -
